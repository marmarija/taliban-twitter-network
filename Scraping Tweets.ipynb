# %% [markdown]
# # Scraping tweets

# %%
import tweepy
import json
import requests
import pandas as pd

consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""

#Inital idea:
#https://www.geeksforgeeks.org/python-api-followers-in-tweepy/

client = tweepy.Client(consumer_key= consumer_key,
                       consumer_secret= consumer_secret,
                       access_token= access_token,
                       access_token_secret= access_token_secret
                        )


# IF one account has max 100 tweets, we don't need paginator, in that case use:
#tweetids = client.get_users_tweets(id='1289055510117748741', start_time='2021-08-01T00:00:00Z', end_time='2021-08-31T00:00:00Z',max_results=100, user_auth=True)


paginator = tweepy.Paginator(
    client.get_users_tweets,               
    "1303030450366165004",                          
    end_time="2021-08-31T00:00:00Z",      
    start_time="2021-05-01T00:00:00Z",   
    #exclude=['retweets', 'replies']
    max_results=100, limit=100, user_auth=True                      
)

# Appeding tweets data to the lists

tweets_data = []
for i in paginator:
    tweets_data.append(i.data)
    print(i)

tweet_ids = []
tweet_text = []

for i in range(0,len(tweets_data)):
    for j in tweets_data[i]:
        tweet_ids.append(j['id'])
# Out:
# Response(data=[<Tweet id=1432451583510519812 text='الحمد لله أولا و آخرا.\nألف مبروك لكل أبناء الوطن والشعب المجاهد العزیز: اليوم  خرجت جميع القوات الأجنبية من أرضنا الطاهرة، عرین الشهداء. ألف مبروك شعبنا الکریم! نرجو الله أن یرزقنا التوفیق والسداد لنبني بلدنا جمیعا معا.'>, <Tweet id=1432450113826402309 text='الحمد لله\n تبریک به همه هموطنان و ملت عزیز و مجاهد خویش: امروز همه نیروهای خارجی از سرزمین پاک و شهید پرور ما خارج شدند.\nملتم مبارکت باشد! از الله متعال استدعا میداریم تا توفیق را نصیب مان کند که دیکر کشورمان را با هم شاد و آباد کنیم.'>, <Tweet id=1432448656322486279 text='الحمد لله\nټولو هیوادوالو او ګران مجاهد ولس ته د خوښۍ زیری:\n نن عملا ټول بهرني ځواکونه زموږ له پاکې او شهید پرورې خاورې څخه ووتل. ولسه مبارک مو شه! \nنور دې لله متعال توفیق راکړي چې په ګډه خپل هېواد اباد کړو.'>, <Tweet id=1432434448851738624 text='2/2 په دې کتنه کې د افغانستان په روانو حالاتو او د کابل په هوايي ډګر کې رامینځته شوي وضعیت خبرې وشوې. ددې ترڅنګ، د اسلامي امارت هئیت نوموړي ته د مختلفو موضوعاتو پ
# ...

# %% [markdown]
# ## For accounts that have less than 100 tweets

# %%
import tweepy
import json
import requests
import pandas as pd

consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""

client = tweepy.Client(consumer_key= consumer_key,
                       consumer_secret= consumer_secret,
                       access_token= access_token,
                       access_token_secret= access_token_secret,
                        return_type = requests.Response)
                      

tweets = client.get_users_tweets(               
    1303030450366165004,                            
    end_time="2021-08-31T00:00:00Z",            
    start_time="2021-05-01T00:00:00Z",   
    #exclude=['retweets', 'replies'],   
    max_results=100, user_auth=True                        
)

# %%
import json
tweets100 = tweets.json()
print(len(tweets100['data']))
# Out:
# 100

# %% [markdown]
# ## Individual tweet data when paginator is used

# %%
import pandas as pd
import requests
import json


json_data = []
for i in paginator:
    json_data.append(i.data)


tweet_ids = []
tweet_text = []

for i in range(0,len(json_data)):
    for j in json_data[i]:
        tweet_ids.append(j['id'])
        tweet_text.append(j['text'])


tweet_time = []
tweet_retweets = []
tweet_lang = []
tweet_txt = []
results_tw = []

for ids in tweet_ids:
    tweet = client.get_tweet(ids, tweet_fields=['created_at,geo,lang'] ,user_auth = True)
    q = tweet.data
    results_tw.append(q)
    print(q)
    tweet_time.append(q['data']['created_at'])
    tweet_txt.append(q['data']['text'])
    tweet_lang.append(q['data']['lang'])
    


# Pravimo dataframe i eksportujemo u csv

df = pd.DataFrame({"Tweet IDs" : tweet_ids, 
                   "Tweet Date": tweet_time,
                   "Tweet Text" : tweet_txt, 
                   "Tweet Lang" : tweet_lang})

df.to_csv("naeem.csv", index=False)
# Out:
# الحمد لله أولا و آخرا.
# ألف مبروك لكل أبناء الوطن والشعب المجاهد العزیز: اليوم  خرجت جميع القوات الأجنبية من أرضنا الطاهرة، عرین الشهداء. ألف مبروك شعبنا الکریم! نرجو الله أن یرزقنا التوفیق والسداد لنبني بلدنا جمیعا معا.
# الحمد لله
#  تبریک به همه هموطنان و ملت عزیز و مجاهد خویش: امروز همه نیروهای خارجی از سرزمین پاک و شهید پرور ما خارج شدند.
# ملتم مبارکت باشد! از الله متعال استدعا میداریم تا توفیق را نصیب مان کند که دیکر کشورمان را با هم شاد و آباد کنیم.
# الحمد لله
# ټولو هیوادوالو او ګران مجاهد ولس ته د خوښۍ زیری:
#  نن عملا ټول بهرني ځواکونه زموږ له پاکې او شهید پرورې خاورې څخه ووتل. ولسه مبارک مو شه!
# نور دې لله متعال توفیق راکړي چې په ګډه خپل هېواد اباد کړو.
# 2/2 په دې کتنه کې د افغانستان په روانو حالاتو او د کابل په هوايي ډګر کې رامینځته شوي وضعیت خبرې وشوې. ددې ترڅنګ، د اسلامي امارت هئیت نوموړي ته د مختلفو موضوعاتو په هکله د امارت پالیسي او موقف  بيان كړ .
# ...

# %%
tweet_retweets = []
tweet_likes = []

retweets = client.get_retweeters(1432443918658965511, user_fields='location' ,user_auth = True)
likes = client.get_liking_users(1432443918658965511, user_fields='location' ,user_auth = True)
q = retweets.json()
r = likes.json()

print(q)
print(r)

# %%
tweet_retweets_ids = []
tweet_retweets_usernames = []
tweet_retweet_ids_list = []
tweet_retweets_usernames_list = []


tweet_likes_ids = []
tweet_likes_usernames = []
tweet_likes_ids_list = []
tweet_likes_usernames_list = []


for ids in lista_tweetova:
    retweets = client.get_retweeters(ids, user_fields='location' ,user_auth = True)
    likes = client.get_liking_users(ids, user_fields='location' ,user_auth = True)
    q = retweets.json()
    r = likes.json()
    print(q)
    print(r)
    for i in q['data']:
        tweet_retweets_ids.append(i['id'])
        tweet_retweets_usernames.append(i['username'])
    tweet_retweet_ids_list.append(tweet_retweets_ids)
    tweet_retweets_usernames_list.append(tweet_retweets_usernames)
    
    for i in r['data']:
        tweet_likes_ids.append(i['id'])
        tweet_likes_usernames.append(i['username']) 
    tweet_likes_ids_list.append(tweet_likes_ids)    
    tweet_likes_usernames_list.append(tweet_likes_usernames)

# %% [markdown]
# ## Getting retweets ids

# %%
import tweepy
import json
import requests
import pandas as pd

consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""

client = tweepy.Client(consumer_key= consumer_key,consumer_secret= consumer_secret,access_token= access_token,access_token_secret= access_token_secret)


tweet_retweets_ids = []
tweet_retweets_usernames = []
tweet_likes_ids = []
tweet_likes_usernames = []

tweet_retweet_ids_list = []
tweet_retweets_usernames_list = []
tweet_likes_ids_list = []
tweet_likes_usernames_list = []


for ids in lista_tweetova:

    paginator_retweets = tweepy.Paginator(
        client.get_retweeters,ids,
        max_results=100, limit=5, user_auth=True                        
    )

    tweets_data_1 = []
    for i in paginator_retweets:
        tweets_data_1.append(i.data)

    for i in range(0,len(tweets_data_1)-1):
        for j in tweets_data_1[i]:
        #tweet_ids.append(j['id'])
        #tweet_text.append(j['text'])
            tweet_retweets_ids.append(j['id'])
            tweet_retweets_usernames.append(j['username'])
        tweet_retweet_ids_list.append(tweet_retweets_ids)
        tweet_retweets_usernames_list.append(tweet_retweets_usernames)
     
    tweets_data_1 = []
    
    paginator_likes = tweepy.Paginator(
        client.get_liking_users,ids,
        max_results=100, limit=5, user_auth=True                        
    )
    
    tweets_data_2 = []
    for i in paginator_likes:
        tweets_data_2.append(i.data)

    for i in range(0,len(tweets_data_2)-1):
        for j in tweets_data_2[i]:
            tweet_likes_ids.append(j['id'])
            tweet_likes_usernames.append(j['username'])
        tweet_likes_ids_list.append(tweet_retweets_ids)
        tweet_likes_usernames_list.append(tweet_retweets_usernames)
        
    tweets_data_2 = []

# %% [markdown]
# ## Getting retweets

# %%
import tweepy
import json
import requests
import pandas as pd
import time

consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""

client = tweepy.Client(consumer_key= consumer_key,consumer_secret= consumer_secret,access_token= access_token,access_token_secret= access_token_secret,wait_on_rate_limit = True)


tweet_retweets_ids = []
tweet_retweets_usernames = []
tweet_likes_ids = []
tweet_likes_usernames = []

tweet_retweet_ids_list = []
tweet_retweets_usernames_list = []
tweet_likes_ids_list = []
tweet_likes_usernames_list = []


retweets_num = []

,1388417568449470465]

tweet_likes_ids = []
tweet_likes_usernames = []


tweet_likes_ids_list = []
tweet_likes_usernames_list = []
likes_num = []


tweets_data_2 = []
temporary_id = []
for i in range(0,265):
    temporary_id.append(tweet_ids[i])
    try:
         
    
        paginator_likes = tweepy.Paginator(
            client.get_liking_users,tweet_ids[i],
            max_results=100, limit=10000, user_auth=True                        
        )
        
        
        #Getting all favorites
        for j in paginator_likes:
            tweets_data_2.append(j.data)
        
        print('Broj stranica u krugu', i)
        print(len(tweets_data_2))
        print('--------------------')
        #Checking pagination details
        for k in range(0,len(tweets_data_2)-1):
            for l in tweets_data_2[k]:
                tweet_likes_ids.append(l['id'])
                tweet_likes_usernames.append(l['username'])
        
        tweet_likes_ids_list.append(tweet_likes_ids)
        tweet_likes_usernames_list.append(tweet_likes_usernames)
        #Total number of favorites        likes_num.append(len(tweet_likes_ids))
        
        tweet_likes_ids = []
        tweet_likes_usernames = []
        tweets_data_2 = []
        
        #Due to Twitter API limitation, adding time sleep so loop doesn't break
        if i %2 == 0:
            #Saving results on every second page, in case the loop breaks
            df = pd.DataFrame({"Tweet IDs" : temporary_id, 
                   "Tweet Username Likes": tweet_likes_usernames_list,
                   "Tweet ID Likes" : tweet_likes_ids_list,
                  "Total Likes": likes_num})
            df.to_csv("SuhailShaheen-like-update-1.csv", index=False)
            time.sleep(140)
        elif i%3 == 0:
            time.sleep(120)
        elif i%4 ==0:    
            time.sleep(110)
        elif i%5 ==0:    
            time.sleep(100)
        elif i%6 ==0:    
            time.sleep(100)    
        else:    
            time.sleep(50)    
    
        
    except StopIteration:
        break



lista_tweetova_1 = []
for i in range(0,265):
    lista_tweetova_1.append(tweet_ids[i])


df = pd.DataFrame({"Tweet IDs" : lista_tweetova_1, 
                   "Tweet Username Likes": tweet_likes_usernames_list,
                   "Tweet ID Likes" : tweet_likes_ids_list,
                  "Total Likes": likes_num})
df.to_csv("SuhailShaheen-0-like.csv", index=False)
# Out:
# 1432459775632105478
# Broj stranica u krugu 0
# 40
# --------------------
# 3591
# ------------------
# 1432459077217660934
# Rate limit exceeded. Sleeping for 729 seconds.
# 1432458237404659716
# Broj stranica u krugu 2
# 54
# --------------------
# 4901
# ------------------
# 1432457860529770497
# Broj stranica u krugu 3
# 38
# --------------------
# 3457
# ------------------
# 1432434656050393092
# Broj stranica u krugu 4
# 6
# --------------------
# 418
# ------------------
# 1432434653537910787
# Rate limit exceeded. Sleeping for 751 seconds.
# Broj stranica u krugu 5
# 12
# --------------------
# 1013
# ------------------
# 1432423254833221635
# 1431815079566221312
# Broj stranica u krugu 7
# 25
# --------------------
# 2255
# ------------------
# 1431673336682225665
# Rate limit exceeded. Sleeping for 819 seconds.
# 1431348284287770630
# Rate limit exceeded. Sleeping for 868 seconds.
# 1431211356913639432
# Broj stranica u krugu 10
# 186
# --------------------
# 17245
# ...
