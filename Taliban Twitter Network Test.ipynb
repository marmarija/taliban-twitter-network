# %%
#install.packages('igraph')
library(igraph)
data <- read.csv("results1.csv", sep=",", row.names=1)
matrx <- as.matrix(data) 
matrx
# Out:
#                 Ali_Albukhaiti AnasHaqqani313 SaeedKhosty QaharBalkhi
# Ali_Albukhaiti  0              0              1           0
# AnasHaqqani313  0              0              1           1
# SaeedKhosty     0              0              0           0
# QaharBalkhi     0              0              1           0
# QyAhmadi21      0              0              0           0
# AbdulHaqHammad2 0              1              1           1
# MuslimKandozi   0              1              0           1
# Ahmadmuttaqi01  0              1              1           1
# MatiullahTuraab 0              0              1           1
# mashaalkasim    0              1              0           1
# Hilal_khan22    0              1              1           0
# MaryamKhpalwak9 0              1              1           1
# Ghazniwall_Ash  0              1              1           1
# Saharsafdare    0              1              1           0
# ...

# %%
amat <- as.matrix(data)
network <- graph_from_adjacency_matrix(amat, mode = c('directed'))

plot(network,  
     vertex.label.cex = .2,
     vertex.size = 4,
     edge.arrow.size = .3)
# Out:
# Plot with title ""

# %%
plot(network, 
     layout=layout_nicely(network),
     vertex.label.cex = .2, 
     edge.arrow.size = 0.3,
     vertex.size=9)
# Out:
# Plot with title ""

# %%
info <- read.csv('test-set.csv')
df1 <- data.frame(info)
print(df1)
# Out:
#    Node.id        Username      User.ID
# 1        1  Ali_Albukhaiti 4.162157e+08
# 2        2  AnasHaqqani313 1.290000e+18
# 3        3     SaeedKhosty 3.255286e+09
# 4        4     QaharBalkhi 1.430000e+18
# 5        5      QyAhmadi21 1.200000e+18
# 6        6 AbdulHaqHammad2 1.230000e+18
# 7        7   MuslimKandozi 1.420000e+18
# 8        8  Ahmadmuttaqi01 1.420000e+18
# 9        9 MatiullahTuraab 1.200000e+18
# 10      10    mashaalkasim 9.018545e+08
# 11      11    Hilal_khan22 1.090000e+18
# 12      12 MaryamKhpalwak9 1.220000e+18
# 13      13  Ghazniwall_Ash 1.410000e+18
# 14      14    Saharsafdare 1.250000e+18
# 15      15   Khalidoumari7 1.460000e+18
# 16      16       H_Ahmadi1 2.504245e+09
# 17      17  Haqqanisab_313 1.480000e+18
# 18      18         SGhar11 1.340000e+18
# 19      19      Taamim_313 1.410000e+18
# 20      20 marziahussaini0 1.290000e+18
# 21      21    dailyshariat 1.340000e+18
# 22      22 waliullahshahen 8.490000e+17
# ...

# %%
plot(network,layout=layout_with_gem(network)
,edge.arrow.size=.3, vertex.size =log(df1$Followers.Count)*1.2,vertex.color=df1$Activity, vertex.label.cex = .5)
# Out:
# Plot with title ""
